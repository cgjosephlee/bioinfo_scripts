# %% [markdown]
# # Test I/O speed

# %%
import io
import gzip
import cProfile

# file = 'test.np.fq'  # 20M
file = '/mnt/nas1/hhl/phellinus/mitochondria/rebuild/pnok/O_PBA/02_0_Sprai_in.fastq'  # 1.5G
# fileGz = 'test.np.fq.gz'  # 12M
fileGz = '/mnt/nas1/hhl/ustilago/fastqs.nanopore/UEMT_FAH91148.fq.gz'  # 2.6G

def op(handle):
    lengths = []
    for line in handle:
        lengths.append(len(next(handle).strip()))
        next(handle)
        next(handle)
    return sum(lengths)

# %%
### uncompressed ###

def funcA(file):
    with open(file, 'rt') as f:
        print(op(f))

def funcB(file):
    with open(file, 'rb') as f:
        print(op(f))

def funcC(file):
    with open(file, 'rb') as f:
        handle = io.TextIOWrapper(f)
        print(op(handle))

def funcD(file):
    with open(file, 'rb') as f:
        handle = io.BufferedReader(f)
        print(op(handle))

# %%
### compressed ###

def funcA_gz(file):
    with gzip.open(fileGz) as f:
        print(op(f))

def funcB_gz(file):
    with io.BufferedReader(gzip.open(fileGz)) as f:
        print(op(f))

def funcC_gz(file):
    with open(fileGz, 'rb') as f:
        h = io.BufferedReader(gzip.GzipFile(fileobj=f))
        print(op(h))

# %% [markdown]
# ## benchmark

# %%
cProfile.run('funcA(file)')
cProfile.run('funcB(file)')
cProfile.run('funcC(file)')
cProfile.run('funcD(file)')
# A > C > D > B
# Out:
# 793548227
#          1132126 function calls in 3.485 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.273    0.273    3.481    3.481 <ipython-input-13-c165535b06d2>:10(op)
#         1    0.002    0.002    3.485    3.485 <ipython-input-3-9fbb4a90202a>:3(funcA)
#         1    0.000    0.000    3.485    3.485 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:23(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 codecs.py:259(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:308(__init__)
#    195021    0.211    0.000    0.659    0.000 codecs.py:318(decode)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:337(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#    195021    0.448    0.000    0.448    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#         1    0.000    0.000    3.485    3.485 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#    123673    0.025    0.000    0.025    0.000 {built-in method builtins.len}
#    371019    2.388    0.000    3.043    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.002    0.002    0.002    0.002 {built-in method builtins.sum}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    123673    0.022    0.000    0.022    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    123673    0.112    0.000    0.112    0.000 {method 'strip' of 'str' objects}
#
#
# 793548227
#          742080 function calls in 1.368 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.226    0.226    1.356    1.356 <ipython-input-13-c165535b06d2>:10(op)
#         1    0.002    0.002    1.367    1.367 <ipython-input-3-9fbb4a90202a>:7(funcB)
#         1    0.000    0.000    1.367    1.367 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:337(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         1    0.000    0.000    1.368    1.368 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#    123673    0.024    0.000    0.024    0.000 {built-in method builtins.len}
#    371019    0.983    0.000    0.983    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.002    0.002    0.002    0.002 {built-in method builtins.sum}
#         1    0.009    0.009    0.009    0.009 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    123673    0.019    0.000    0.019    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    123673    0.102    0.000    0.102    0.000 {method 'strip' of 'bytes' objects}
#
#
# 793548227
#          1132126 function calls in 3.017 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.259    0.259    3.004    3.004 <ipython-input-13-c165535b06d2>:10(op)
#         1    0.002    0.002    3.017    3.017 <ipython-input-3-9fbb4a90202a>:11(funcC)
#         1    0.000    0.000    3.017    3.017 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:23(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 codecs.py:259(__init__)
#         1    0.000    0.000    0.000    0.000 codecs.py:308(__init__)
#    195021    0.207    0.000    0.653    0.000 codecs.py:318(decode)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:337(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#    195021    0.446    0.000    0.446    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#         1    0.000    0.000    3.017    3.017 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#    123673    0.025    0.000    0.025    0.000 {built-in method builtins.len}
#    371019    1.935    0.000    2.584    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.002    0.002    0.002    0.002 {built-in method builtins.sum}
#         1    0.011    0.011    0.011    0.011 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    123673    0.021    0.000    0.021    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    123673    0.109    0.000    0.109    0.000 {method 'strip' of 'str' objects}
#
#
# 793548227
#          742080 function calls in 2.383 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.262    0.262    2.375    2.375 <ipython-input-13-c165535b06d2>:10(op)
#         1    0.002    0.002    2.383    2.383 <ipython-input-3-9fbb4a90202a>:16(funcD)
#         1    0.000    0.000    2.383    2.383 <string>:1(<module>)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:337(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         1    0.000    0.000    2.383    2.383 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#    123673    0.022    0.000    0.022    0.000 {built-in method builtins.len}
#    371019    1.961    0.000    1.961    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.002    0.002    0.002    0.002 {built-in method builtins.sum}
#         1    0.006    0.006    0.006    0.006 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    123673    0.020    0.000    0.020    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    123673    0.107    0.000    0.107    0.000 {method 'strip' of 'bytes' objects}

# %%
cProfile.run('funcA_gz(file)')
cProfile.run('funcB_gz(file)')
cProfile.run('funcC_gz(file)')
# A > B = C
# Out:
# 2334796854
#          20937836 function calls in 60.264 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.008    0.008   60.264   60.264 <ipython-input-4-6734752522f5>:3(funcA_gz)
#         1    1.662    1.662   60.254   60.254 <ipython-input-9-811626be1f1f>:9(op)
#         1    0.000    0.000   60.264   60.264 <string>:1(<module>)
#   2222481    1.208    0.000    1.784    0.000 _compression.py:12(_check_not_closed)
#         1    0.000    0.000    0.000    0.000 _compression.py:150(tell)
#         1    0.000    0.000    0.000    0.000 _compression.py:36(readable)
#         1    0.000    0.000    0.000    0.000 _compression.py:39(__init__)
#         1    0.000    0.000    0.000    0.000 _compression.py:59(close)
#    580941    2.559    0.000   45.855    0.000 _compression.py:66(readinto)
#         1    0.000    0.000    0.001    0.001 gzip.py:123(__init__)
#         1    0.000    0.000    0.001    0.001 gzip.py:20(open)
#   2222484    0.576    0.000    0.576    0.000 gzip.py:298(closed)
#         1    0.000    0.000    0.001    0.001 gzip.py:302(close)
#   2222481    2.313    0.000   56.233    0.000 gzip.py:372(readline)
#         1    0.000    0.000    0.000    0.000 gzip.py:378(__init__)
#         2    0.000    0.000    0.000    0.000 gzip.py:385(_init_read)
#         2    0.000    0.000    0.000    0.000 gzip.py:389(_read_exact)
#         2    0.000    0.000    0.000    0.000 gzip.py:405(_read_gzip_header)
#    580941    2.536    0.000   42.761    0.000 gzip.py:438(read)
#    580940    0.803    0.000    7.845    0.000 gzip.py:489(_add_read_data)
#         1    0.000    0.000    0.000    0.000 gzip.py:493(_read_eof)
#         1    0.000    0.000    0.000    0.000 gzip.py:74(__init__)
#    580945    1.635    0.000    2.978    0.000 gzip.py:80(read)
#    580940    0.710    0.000    0.837    0.000 gzip.py:93(prepend)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:337(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         2    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         1    0.000    0.000   60.264   60.264 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#   4041266    0.694    0.000    0.694    0.000 {built-in method builtins.len}
#   1666860    1.730    0.000   55.288    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.011    0.011    0.011    0.011 {built-in method builtins.sum}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#    580942    6.946    0.000    6.946    0.000 {built-in method zlib.crc32}
#         2    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         1    0.000    0.000    0.000    0.000 {function DecompressReader.close at 0x7f275b255b70}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    555620    0.109    0.000    0.109    0.000 {method 'append' of 'list' objects}
#    580941    0.246    0.000    0.246    0.000 {method 'cast' of 'memoryview' objects}
#         2    0.001    0.000    0.001    0.000 {method 'close' of '_io.BufferedReader' objects}
#    580940   28.482    0.000   28.482    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    580944    1.343    0.000    1.343    0.000 {method 'read' of '_io.BufferedReader' objects}
#   2222481    6.281    0.000   52.137    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#    555620    0.409    0.000    0.409    0.000 {method 'strip' of 'bytes' objects}
#
#
# 2334796854
#          16594181 function calls (16013236 primitive calls) in 57.042 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.008    0.008   57.042   57.042 <ipython-input-4-6734752522f5>:7(funcB_gz)
#         1    1.554    1.554   57.000   57.000 <ipython-input-9-811626be1f1f>:9(op)
#         1    0.000    0.000   57.042   57.042 <string>:1(<module>)
#    580943    0.321    0.000    0.472    0.000 _compression.py:12(_check_not_closed)
#         1    0.000    0.000    0.000    0.000 _compression.py:120(seek)
#         1    0.000    0.000    0.000    0.000 _compression.py:150(tell)
#         1    0.000    0.000    0.000    0.000 _compression.py:36(readable)
#         1    0.000    0.000    0.000    0.000 _compression.py:39(__init__)
#         1    0.000    0.000    0.000    0.000 _compression.py:59(close)
#         1    0.000    0.000    0.000    0.000 _compression.py:63(seekable)
#    580942    2.571    0.000   45.957    0.000 _compression.py:66(readinto)
#         1    0.000    0.000    0.000    0.000 gzip.py:107(seekable)
#         1    0.000    0.000    0.033    0.033 gzip.py:123(__init__)
#         1    0.000    0.000    0.033    0.033 gzip.py:20(open)
#    580941    0.826    0.000   49.003    0.000 gzip.py:271(read)
#   2803429    0.718    0.000    0.718    0.000 gzip.py:298(closed)
#         1    0.000    0.000    0.001    0.001 gzip.py:302(close)
#         1    0.000    0.000    0.000    0.000 gzip.py:321(flush)
#         1    0.000    0.000    0.000    0.000 gzip.py:343(readable)
#         1    0.000    0.000    0.000    0.000 gzip.py:352(seek)
#         1    0.000    0.000    0.000    0.000 gzip.py:378(__init__)
#         3    0.000    0.000    0.000    0.000 gzip.py:385(_init_read)
#         2    0.000    0.000    0.000    0.000 gzip.py:389(_read_exact)
#         3    0.000    0.000    0.000    0.000 gzip.py:405(_read_gzip_header)
#    580942    2.549    0.000   42.848    0.000 gzip.py:438(read)
#    580940    0.801    0.000    7.847    0.000 gzip.py:489(_add_read_data)
#         1    0.000    0.000    0.000    0.000 gzip.py:493(_read_eof)
#         1    0.000    0.000    0.000    0.000 gzip.py:74(__init__)
#    580946    1.665    0.000    2.998    0.000 gzip.py:80(read)
#    580940    0.720    0.000    0.842    0.000 gzip.py:93(prepend)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:337(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         2    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         1    0.000    0.000   57.042   57.042 {built-in method builtins.exec}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#   4041269    0.692    0.000    0.692    0.000 {built-in method builtins.len}
#   1666860    5.258    0.000   53.801    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.006    0.006    0.006    0.006 {built-in method builtins.sum}
#         1    0.033    0.033    0.033    0.033 {built-in method io.open}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#    580943    6.957    0.000    6.957    0.000 {built-in method zlib.crc32}
#         2    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         1    0.000    0.000    0.000    0.000 {function DecompressReader.close at 0x7f275b255b70}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    555620    0.100    0.000    0.100    0.000 {method 'append' of 'list' objects}
#    580942    0.249    0.000    0.249    0.000 {method 'cast' of 'memoryview' objects}
#         2    0.001    0.000    0.001    0.001 {method 'close' of '_io.BufferedReader' objects}
#    580940   28.518    0.000   28.518    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# 1161886/580941    3.080    0.000   47.704    0.000 {method 'read' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#    555620    0.414    0.000    0.414    0.000 {method 'strip' of 'bytes' objects}
# 2334796854
#          16594178 function calls (16013233 primitive calls) in 57.302 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.009    0.009   57.301   57.301 <ipython-input-4-6734752522f5>:11(funcC_gz)
#         1    1.573    1.573   57.255   57.255 <ipython-input-9-811626be1f1f>:9(op)
#         1    0.000    0.000   57.301   57.301 <string>:1(<module>)
#    580943    0.321    0.000    0.466    0.000 _compression.py:12(_check_not_closed)
#         1    0.000    0.000    0.000    0.000 _compression.py:120(seek)
#         1    0.000    0.000    0.000    0.000 _compression.py:150(tell)
#         1    0.000    0.000    0.000    0.000 _compression.py:36(readable)
#         1    0.000    0.000    0.000    0.000 _compression.py:39(__init__)
#         1    0.000    0.000    0.000    0.000 _compression.py:59(close)
#         1    0.000    0.000    0.000    0.000 _compression.py:63(seekable)
#    580942    2.628    0.000   46.130    0.000 _compression.py:66(readinto)
#         1    0.000    0.000    0.000    0.000 gzip.py:107(seekable)
#         1    0.000    0.000    0.000    0.000 gzip.py:123(__init__)
#    580941    0.815    0.000   49.197    0.000 gzip.py:271(read)
#   2803428    0.684    0.000    0.684    0.000 gzip.py:298(closed)
#         1    0.000    0.000    0.000    0.000 gzip.py:302(close)
#         1    0.000    0.000    0.000    0.000 gzip.py:321(flush)
#         1    0.000    0.000    0.000    0.000 gzip.py:343(readable)
#         1    0.000    0.000    0.000    0.000 gzip.py:352(seek)
#         1    0.000    0.000    0.000    0.000 gzip.py:378(__init__)
#         3    0.000    0.000    0.000    0.000 gzip.py:385(_init_read)
#         2    0.000    0.000    0.000    0.000 gzip.py:389(_read_exact)
#         3    0.000    0.000    0.001    0.000 gzip.py:405(_read_gzip_header)
#    580942    2.534    0.000   42.951    0.000 gzip.py:438(read)
#    580940    0.801    0.000    7.864    0.000 gzip.py:489(_add_read_data)
#         1    0.000    0.000    0.000    0.000 gzip.py:493(_read_eof)
#         1    0.000    0.000    0.000    0.000 gzip.py:74(__init__)
#    580946    1.669    0.000    3.002    0.000 gzip.py:80(read)
#    580940    0.717    0.000    0.841    0.000 gzip.py:93(prepend)
#         3    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:382(write)
#         3    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         3    0.000    0.000    0.000    0.000 socket.py:337(send)
#         3    0.000    0.000    0.000    0.000 threading.py:1062(_wait_for_tstate_lock)
#         3    0.000    0.000    0.000    0.000 threading.py:1104(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:506(is_set)
#         2    0.000    0.000    0.000    0.000 {built-in method _struct.unpack}
#         1    0.000    0.000   57.302   57.302 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#   4041269    0.699    0.000    0.699    0.000 {built-in method builtins.len}
#   1666860    5.340    0.000   54.052    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.006    0.006    0.006    0.006 {built-in method builtins.sum}
#         1    0.037    0.037    0.037    0.037 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#    580943    6.973    0.000    6.973    0.000 {built-in method zlib.crc32}
#         2    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         1    0.000    0.000    0.000    0.000 {function DecompressReader.close at 0x7f275b255b70}
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    555620    0.103    0.000    0.103    0.000 {method 'append' of 'list' objects}
#    580942    0.256    0.000    0.256    0.000 {method 'cast' of 'memoryview' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#    580940   28.617    0.000   28.617    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# 1161886/580941    3.120    0.000   47.916    0.000 {method 'read' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#    555620    0.400    0.000    0.400    0.000 {method 'strip' of 'bytes' objects}
